# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
election = pd.read_csv('pennsylvania2012_turnout.csv', index_col="county")
election
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Adams           PA   41973  35.482334  63.112001  Romney   61156  68.632677
# Allegheny       PA  614671  56.640219  42.185820   Obama  924351  66.497575
# Armstrong       PA   28322  30.696985  67.901278  Romney   42147  67.198140
# Beaver          PA   80015  46.032619  52.637630  Romney  115157  69.483401
# Bedford         PA   21444  22.057452  76.986570  Romney   32189  66.619031
# ...            ...     ...        ...        ...     ...     ...        ...
# Washington      PA   90078  42.744066  56.012567  Romney  142331  63.287689
# Wayne           PA   20966  38.815225  59.768196  Romney   32577  64.358290
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
# Wyoming         PA   11214  42.910647  55.189941  Romney   17255  64.989858
# York            PA  186394  38.695452  59.860296  Romney  280280  66.502783
#
#                  margin
# county
# ...

# %%
result = election[["winner", "total", "voters"]]
# Out:
#            winner   total  voters
# county
# Adams      Romney   41973   61156
# Allegheny   Obama  614671  924351
# Armstrong  Romney   28322   42147
# Beaver     Romney   80015  115157
# Bedford    Romney   21444   32189
# Berks      Romney  163253  250356
# Blair      Romney   47631   85328
# Bradford   Romney   22501   40490
# Bucks       Obama  319407  435606
# Butler     Romney   88924  122762

# %%
election.loc["Perry":"Potter"]
# Out:
#              state   total      Obama     Romney  winner   voters    turnout  \
# county
# Perry           PA   18240  29.769737  68.591009  Romney    27245  66.948064
# Philadelphia    PA  653598  85.224251  14.051451   Obama  1099197  59.461407
# Pike            PA   23164  43.904334  54.882576  Romney    41840  55.363289
# Potter          PA    7205  26.259542  72.158223  Romney    10913  66.022175
#
#                  margin
# county
# Perry         38.821272
# Philadelphia  71.172800
# Pike          10.978242
# Potter        45.898681

# %%
election.loc["Potter":"Perry":-1]
# Out:
#              state   total      Obama     Romney  winner   voters    turnout  \
# county
# Potter          PA    7205  26.259542  72.158223  Romney    10913  66.022175
# Pike            PA   23164  43.904334  54.882576  Romney    41840  55.363289
# Philadelphia    PA  653598  85.224251  14.051451   Obama  1099197  59.461407
# Perry           PA   18240  29.769737  68.591009  Romney    27245  66.948064
#
#                  margin
# county
# Potter        45.898681
# Pike          10.978242
# Philadelphia  71.172800
# Perry         38.821272

# %%
election.loc[:, :"Obama"]
# Out:
#              state   total      Obama
# county
# Adams           PA   41973  35.482334
# Allegheny       PA  614671  56.640219
# Armstrong       PA   28322  30.696985
# Beaver          PA   80015  46.032619
# Bedford         PA   21444  22.057452
# ...            ...     ...        ...
# Washington      PA   90078  42.744066
# Wayne           PA   20966  38.815225
# Westmoreland    PA  168709  37.567646
# Wyoming         PA   11214  42.910647
# York            PA  186394  38.695452
#
# [67 rows x 3 columns]

# %%
election.loc[:, "Obama":"winner"]
# Out:
#                   Obama     Romney  winner
# county
# Adams         35.482334  63.112001  Romney
# Allegheny     56.640219  42.185820   Obama
# Armstrong     30.696985  67.901278  Romney
# Beaver        46.032619  52.637630  Romney
# Bedford       22.057452  76.986570  Romney
# ...                 ...        ...     ...
# Washington    42.744066  56.012567  Romney
# Wayne         38.815225  59.768196  Romney
# Westmoreland  37.567646  61.306154  Romney
# Wyoming       42.910647  55.189941  Romney
# York          38.695452  59.860296  Romney
#
# [67 rows x 3 columns]

# %%
election.loc[:, "Romney":]
# Out:
#                  Romney  winner  voters    turnout     margin
# county
# Adams         63.112001  Romney   61156  68.632677  27.629667
# Allegheny     42.185820   Obama  924351  66.497575  14.454399
# Armstrong     67.901278  Romney   42147  67.198140  37.204293
# Beaver        52.637630  Romney  115157  69.483401   6.605012
# Bedford       76.986570  Romney   32189  66.619031  54.929118
# ...                 ...     ...     ...        ...        ...
# Washington    56.012567  Romney  142331  63.287689  13.268501
# Wayne         59.768196  Romney   32577  64.358290  20.952971
# Westmoreland  61.306154  Romney  238006  70.884347  23.738508
# Wyoming       55.189941  Romney   17255  64.989858  12.279294
# York          59.860296  Romney  280280  66.502783  21.164844
#
# [67 rows x 5 columns]

# %%
rows = ["Philadelphia", "Centre", "Fulton"]
cols = ["winner", "Obama", "Romney"]
election.loc[rows, cols]
# Out:
#               winner      Obama     Romney
# county
# Philadelphia   Obama  85.224251  14.051451
# Centre        Romney  48.948416  48.977486
# Fulton        Romney  21.096291  77.748861

# %%
election[election["turnout"] > 70]
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Bucks           PA  319407  49.966970  48.801686   Obama  435606  73.324748
# Butler          PA   88924  31.920516  66.816607  Romney  122762  72.436096
# Chester         PA  248295  49.228539  49.650617  Romney  337822  73.498766
# Forest          PA    2308  38.734835  59.835355  Romney    3232  71.410891
# Franklin        PA   62802  30.110506  68.583803  Romney   87406  71.850903
# Montgomery      PA  401787  56.637223  42.286834   Obama  551105  72.905708
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
#
#                  margin
# county
# Bucks          1.165284
# Butler        34.896091
# Chester        0.422079
# Forest        21.100520
# Franklin      38.473297
# Montgomery    14.350390
# Westmoreland  23.738508

# %%
election.loc[election["margin"] < 1, "winner"] = np.nan
election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67 entries, Adams to York
# Data columns (total 8 columns):
# state      67 non-null object
# total      67 non-null int64
# Obama      67 non-null float64
# Romney     67 non-null float64
# winner     64 non-null object
# voters     67 non-null int64
# turnout    67 non-null float64
# margin     67 non-null float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 4.7+ KB

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.dropna(how="any").shape
# Out:
# (0, 14)

# %%
titanic.dropna(how="all").shape
# Out:
# (1309, 14)

# %%
titanic.dropna(thresh=1000, axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
# pclass      1309 non-null int64
# survived    1309 non-null int64
# name        1309 non-null object
# sex         1309 non-null object
# age         1046 non-null float64
# sibsp       1309 non-null int64
# parch       1309 non-null int64
# ticket      1309 non-null object
# fare        1308 non-null float64
# embarked    1307 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %%
def to_celsius(F):
    return (5/9*(F - 32)).astype("int64")

# %%
weather = pd.read_csv("pittsburgh2013.csv")
weather
# Out:
#            Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2013-1-1                32                 28                21
# 1      2013-1-2                25                 21                17
# 2      2013-1-3                32                 24                16
# 3      2013-1-4                30                 28                27
# 4      2013-1-5                34                 30                25
# ..          ...               ...                ...               ...
# 360  2013-12-27                41                 34                27
# 361  2013-12-28                52                 43                34
# 362  2013-12-29                44                 42                39
# 363  2013-12-30                41                 32                23
# 364  2013-12-31                26                 24                23
#
#      Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 23 columns):
# Date                         365 non-null object
# Max TemperatureF             365 non-null int64
# Mean TemperatureF            365 non-null int64
# Min TemperatureF             365 non-null int64
# Max Dew PointF               365 non-null int64
# Mean Dew PointF              365 non-null int64
# Min DewpointF                365 non-null int64
# Max Humidity                 365 non-null int64
# Mean Humidity                365 non-null int64
# Min Humidity                 365 non-null int64
# Max Sea Level PressureIn     365 non-null float64
# Mean Sea Level PressureIn    365 non-null float64
# Min Sea Level PressureIn     365 non-null float64
# Max VisibilityMiles          365 non-null int64
# Mean VisibilityMiles         365 non-null int64
# Min VisibilityMiles          365 non-null int64
# Max Wind SpeedMPH            365 non-null int64
# ...

# %%
weather[["Mean TemperatureF", "Mean Dew PointF"]].apply(to_celsius)
# Out:
#      Mean TemperatureF  Mean Dew PointF
# 0                   -2               -2
# 1                   -6              -11
# 2                   -4               -9
# 3                   -2               -7
# 4                   -1               -6
# ..                 ...              ...
# 360                  1               -6
# 361                  6               -4
# 362                  5                2
# 363                  0               -6
# 364                 -4               -8
#
# [365 rows x 2 columns]

# %%
red_vs_blue = {"Obama": "blue", "Romney": "red"}
election["color"] = election["winner"].map(red_vs_blue)
election
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Adams           PA   41973  35.482334  63.112001  Romney   61156  68.632677
# Allegheny       PA  614671  56.640219  42.185820   Obama  924351  66.497575
# Armstrong       PA   28322  30.696985  67.901278  Romney   42147  67.198140
# Beaver          PA   80015  46.032619  52.637630  Romney  115157  69.483401
# Bedford         PA   21444  22.057452  76.986570  Romney   32189  66.619031
# ...            ...     ...        ...        ...     ...     ...        ...
# Washington      PA   90078  42.744066  56.012567  Romney  142331  63.287689
# Wayne           PA   20966  38.815225  59.768196  Romney   32577  64.358290
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
# Wyoming         PA   11214  42.910647  55.189941  Romney   17255  64.989858
# York            PA  186394  38.695452  59.860296  Romney  280280  66.502783
#
#                  margin color
# county
# ...

# %%
from scipy.stats import zscore

election["turnout_zscore"] = zscore(election["turnout"])
election
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Adams           PA   41973  35.482334  63.112001  Romney   61156  68.632677
# Allegheny       PA  614671  56.640219  42.185820   Obama  924351  66.497575
# Armstrong       PA   28322  30.696985  67.901278  Romney   42147  67.198140
# Beaver          PA   80015  46.032619  52.637630  Romney  115157  69.483401
# Bedford         PA   21444  22.057452  76.986570  Romney   32189  66.619031
# ...            ...     ...        ...        ...     ...     ...        ...
# Washington      PA   90078  42.744066  56.012567  Romney  142331  63.287689
# Wayne           PA   20966  38.815225  59.768196  Romney   32577  64.358290
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
# Wyoming         PA   11214  42.910647  55.189941  Romney   17255  64.989858
# York            PA  186394  38.695452  59.860296  Romney  280280  66.502783
#
#                  margin  turnout_zscore
# ...

# %%
sales = pd.read_csv("sales.csv", index_col=0)
sales
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
sales.index = sales.index.str.upper()
sales
# Out:
#        eggs  salt  spam
# month
# JAN      47  12.0    17
# FEB     110  50.0    31
# MAR     221  89.0    72
# APR      77  87.0    20
# MAY     132   NaN    52
# JUN     205  60.0    55

# %%
sales.index.name = "MONTH"
sales.columns.name = "PRODUCTS"
sales
# Out:
# PRODUCTS  eggs  salt  spam
# MONTH
# JAN         47  12.0    17
# FEB        110  50.0    31
# MAR        221  89.0    72
# APR         77  87.0    20
# MAY        132   NaN    52
# JUN        205  60.0    55

# %%
sales = pd.read_csv("sales.csv")
sales
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
sales["month"] = [1, 2, 1, 2, 1, 2]
sales["state"] = ["CA", "CA", "NY", "NY", "TX", "TX"]
sales
# Out:
#    month  eggs  salt  spam state
# 0      1    47  12.0    17    CA
# 1      2   110  50.0    31    CA
# 2      1   221  89.0    72    NY
# 3      2    77  87.0    20    NY
# 4      1   132   NaN    52    TX
# 5      2   205  60.0    55    TX

# %%
sales.set_index(["state", "month"], inplace=True)
sales
# Out:
#              eggs  salt  spam
# state month
# CA    1        47  12.0    17
#       2       110  50.0    31
# NY    1       221  89.0    72
#       2        77  87.0    20
# TX    1       132   NaN    52
#       2       205  60.0    55

# %%
sales.loc[["CA", "TX"]]
# Out:
#              eggs  salt  spam
# state month
# CA    1        47  12.0    17
#       2       110  50.0    31
# TX    1       132   NaN    52
#       2       205  60.0    55

# %%
sales["CA":"TX"]
# Out:
#              eggs  salt  spam
# state month
# CA    1        47  12.0    17
#       2       110  50.0    31
# NY    1       221  89.0    72
#       2        77  87.0    20
# TX    1       132   NaN    52
#       2       205  60.0    55

# %%
sales.reset_index(inplace=True)
sales.set_index("state", inplace=True)
sales
# Out:
#        month  eggs  salt  spam
# state
# CA         1    47  12.0    17
# CA         2   110  50.0    31
# NY         1   221  89.0    72
# NY         2    77  87.0    20
# TX         1   132   NaN    52
# TX         2   205  60.0    55

# %%
sales.loc["NY"]
# Out:
#        month  eggs  salt  spam
# state
# NY         1   221  89.0    72
# NY         2    77  87.0    20

# %%
sales.reset_index(inplace=True)
sales.set_index(["state", "month"], inplace=True)
sales
# Out:
#              eggs  salt  spam
# state month
# CA    1        47  12.0    17
#       2       110  50.0    31
# NY    1       221  89.0    72
#       2        77  87.0    20
# TX    1       132   NaN    52
#       2       205  60.0    55

# %%
sales.loc["NY"]
# Out:
#        eggs  salt  spam
# month
# 1       221  89.0    72
# 2        77  87.0    20

# %%
sales.loc[("NY", 1), :]
# Out:
# eggs    221.0
# salt     89.0
# spam     72.0
# Name: (NY, 1), dtype: float64

# %%
sales.loc[(["CA", "TX"], 2), :]
# Out:
#              eggs  salt  spam
# state month
# CA    2       110  50.0    31
# TX    2       205  60.0    55

# %%
sales.loc[(slice(None), 2), :]
# Out:
#              eggs  salt  spam
# state month
# CA    2       110  50.0    31
# NY    2        77  87.0    20
# TX    2       205  60.0    55

# %%
users = pd.read_csv('users.csv', index_col=0)
users
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
visitors = users.pivot(index="weekday", columns="city", values="visitors")
visitors
# Out:
# city     Austin  Dallas
# weekday
# Mon         326     456
# Sun         139     237

# %%
signups = users.pivot(index="weekday", columns="city", values="signups")
signups
# Out:
# city     Austin  Dallas
# weekday
# Mon           3       5
# Sun           7      12

# %%
pivot = users.pivot(index="weekday", columns="city")
pivot
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
pivot.columns
# Out:
# MultiIndex([('visitors', 'Austin'),
#             ('visitors', 'Dallas'),
#             ( 'signups', 'Austin'),
#             ( 'signups', 'Dallas')],
#            names=[None, 'city'])

# %%
pivot.loc["Mon", ("visitors", "Austin")]
# Out:
# 326

# %%
pivot.loc["Mon", ("visitors", slice(None))]
# Out:
#           city
# visitors  Austin    326
#           Dallas    456
# Name: Mon, dtype: int64

# %%
pivot.loc["Mon", ("visitors", )]
# Out:
# city
# Austin    326
# Dallas    456
# Name: Mon, dtype: int64

# %%
pivot.loc["Mon", (slice(None), "Austin")]
# Out:
#           city
# visitors  Austin    326
# signups   Austin      3
# Name: Mon, dtype: int64

# %%
pivot[("visitors", "Austin")]
# Out:
# weekday
# Mon    326
# Sun    139
# Name: (visitors, Austin), dtype: int64

# %%
pivot.loc[:, ("visitors", "Austin")]
# Out:
# weekday
# Mon    326
# Sun    139
# Name: (visitors, Austin), dtype: int64

# %%
users_idxed = users.set_index(["city", "weekday"])
users_idxed
# Out:
#                 visitors  signups
# city   weekday
# Austin Sun           139        7
# Dallas Sun           237       12
# Austin Mon           326        3
# Dallas Mon           456        5

# %%
users_sorted = users_idxed.sort_values(["city", "weekday"])
users_sorted
# Out:
#                 visitors  signups
# city   weekday
# Austin Mon           326        3
#        Sun           139        7
# Dallas Mon           456        5
#        Sun           237       12

# %%
users_unstack = users_sorted.unstack("weekday")
users_unstack
# Out:
#         visitors      signups
# weekday      Mon  Sun     Mon Sun
# city
# Austin       326  139       3   7
# Dallas       456  237       5  12

# %%
users_stack = users_unstack.stack("weekday")
users_stack
# Out:
#                 visitors  signups
# city   weekday
# Austin Mon           326        3
#        Sun           139        7
# Dallas Mon           456        5
#        Sun           237       12

# %%
pivot
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
new = pivot.stack("city")
new
# Out:
#                 visitors  signups
# weekday city
# Mon     Austin       326        3
#         Dallas       456        5
# Sun     Austin       139        7
#         Dallas       237       12

# %%
newer = new.swaplevel(0, 1)
newer
# Out:
#                 visitors  signups
# city   weekday
# Austin Mon           326        3
# Dallas Mon           456        5
# Austin Sun           139        7
# Dallas Sun           237       12

# %%
newest = newer.sort_index()
newest
# Out:
#                 visitors  signups
# city   weekday
# Austin Mon           326        3
#        Sun           139        7
# Dallas Mon           456        5
#        Sun           237       12

# %%
newest.equals(users_sorted)
# Out:
# True

# %%
visitors
# Out:
# city     Austin  Dallas
# weekday
# Mon         326     456
# Sun         139     237

# %%
visitors.reset_index()
# Out:
# city weekday  Austin  Dallas
# 0        Mon     326     456
# 1        Sun     139     237

# %%
visitors.reset_index().columns
# Out:
# Index(['weekday', 'Austin', 'Dallas'], dtype='object', name='city')

# %%
pd.melt(visitors.reset_index(), id_vars=["weekday"], value_name="visitors")
# Out:
#   weekday    city  visitors
# 0     Mon  Austin       326
# 1     Sun  Austin       139
# 2     Mon  Dallas       456
# 3     Sun  Dallas       237

# %%
users
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
pd.melt(users)
# Out:
#     variable   value
# 0    weekday     Sun
# 1    weekday     Sun
# 2    weekday     Mon
# 3    weekday     Mon
# 4       city  Austin
# 5       city  Dallas
# 6       city  Austin
# 7       city  Dallas
# 8   visitors     139
# 9   visitors     237
# 10  visitors     326
# 11  visitors     456
# 12   signups       7
# 13   signups      12
# 14   signups       3
# 15   signups       5

# %%
pd.melt(users, id_vars=["weekday", "city"], var_name="type", value_name="customer")
# Out:
#   weekday    city      type  customer
# 0     Sun  Austin  visitors       139
# 1     Sun  Dallas  visitors       237
# 2     Mon  Austin  visitors       326
# 3     Mon  Dallas  visitors       456
# 4     Sun  Austin   signups         7
# 5     Sun  Dallas   signups        12
# 6     Mon  Austin   signups         3
# 7     Mon  Dallas   signups         5

# %%
users_idxed
# Out:
#                 visitors  signups
# city   weekday
# Austin Sun           139        7
# Dallas Sun           237       12
# Austin Mon           326        3
# Dallas Mon           456        5

# %%
pd.melt(users_idxed)
# Out:
#    variable  value
# 0  visitors    139
# 1  visitors    237
# 2  visitors    326
# 3  visitors    456
# 4   signups      7
# 5   signups     12
# 6   signups      3
# 7   signups      5

# %%
pd.melt(users_idxed, col_level=0)
# Out:
#    variable  value
# 0  visitors    139
# 1  visitors    237
# 2  visitors    326
# 3  visitors    456
# 4   signups      7
# 5   signups     12
# 6   signups      3
# 7   signups      5

# %%
users
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
pivot_table = users.pivot_table(index="weekday", columns="city")
pivot_table
# Out:
#         signups        visitors
# city     Austin Dallas   Austin Dallas
# weekday
# Mon           3      5      326    456
# Sun           7     12      139    237

# %%
users.pivot(index="weekday", columns="city")
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
pivot
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
pivot_table.__dict__
# Out:
# {'_is_copy': None, '_data': BlockManager
#  Items: MultiIndex([( 'signups', 'Austin'),
#              ( 'signups', 'Dallas'),
#              ('visitors', 'Austin'),
#              ('visitors', 'Dallas')],
#             names=[None, 'city'])
#  Axis 1: Index(['Mon', 'Sun'], dtype='object', name='weekday')
#  IntBlock: slice(0, 4, 1), 4 x 2, dtype: int64, '_item_cache': {('signups',
#    'Austin'): weekday
#   Mon    3
#   Sun    7
#   Name: (signups, Austin), dtype: int64,
#   ('signups', 'Dallas'): weekday
#   Mon     5
#   Sun    12
#   Name: (signups, Dallas), dtype: int64,
#   ('visitors', 'Austin'): weekday
#   Mon    326
#   Sun    139
#   Name: (visitors, Austin), dtype: int64,
#   ('visitors', 'Dallas'): weekday
#   Mon    456
#   Sun    237
#   Name: (visitors, Dallas), dtype: int64}}

# %%
pivot.__dict__
# Out:
# {'_is_copy': None, '_data': BlockManager
#  Items: MultiIndex([('visitors', 'Austin'),
#              ('visitors', 'Dallas'),
#              ( 'signups', 'Austin'),
#              ( 'signups', 'Dallas')],
#             names=[None, 'city'])
#  Axis 1: Index(['Mon', 'Sun'], dtype='object', name='weekday')
#  IntBlock: slice(0, 4, 1), 4 x 2, dtype: int64, '_item_cache': {('visitors',
#    'Austin'): weekday
#   Mon    326
#   Sun    139
#   Name: (visitors, Austin), dtype: int64}}

# %%
users
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
users.pivot_table(index="weekday", aggfunc="count")
# Out:
#          city  signups  visitors
# weekday
# Mon         2        2         2
# Sun         2        2         2

# %%
users.pivot_table(index="weekday", aggfunc=len)
# Out:
#          city  signups  visitors
# weekday
# Mon         2        2         2
# Sun         2        2         2

# %%
users.pivot_table(index="weekday", aggfunc=sum)
# Out:
#          signups  visitors
# weekday
# Mon            8       782
# Sun           19       376

# %%
users.pivot_table(index="weekday")
# Out:
#          signups  visitors
# weekday
# Mon          4.0       391
# Sun          9.5       188

# %%
users.pivot_table(index="weekday", aggfunc=sum, margins=True)
# Out:
#          signups  visitors
# weekday
# Mon            8       782
# Sun           19       376
# All           27      1158

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                          "bar", "bar", "bar", "bar"],
                    "B": ["one", "one", "one", "two", "two",
                          "one", "one", "two", "two"],
                    "C": ["small", "large", "large", "small",
                          "small", "large", "small", "small",
                          "large"],
                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                    "E": [1, 2, 2, 3, 3, 4, 5, 6, 7]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  1
# 1  foo  one  large  2  2
# 2  foo  one  large  2  2
# 3  foo  two  small  3  3
# 4  foo  two  small  3  3
# 5  bar  one  large  4  4
# 6  bar  one  small  5  5
# 7  bar  two  small  6  6
# 8  bar  two  large  7  7

# %%
df.pivot_table(values="D", index=["A", "B"], columns=["C"], aggfunc=np.sum, fill_value=0, margins=True, dropna=False, margins_name="Total")
# Out:
# C          large  small  Total
# A     B
# bar   one      4      5      9
#       two      7      6     13
# foo   one      4      1      5
#       two      0      6      6
# Total         15     18     33

# %%
table = df.pivot_table(values=['D', 'E'], index=['A', 'C'], 
            aggfunc={'D': np.mean, 'E': [min, max, np.mean]})
table
# Out:
#                   D    E
#                mean  max      mean  min
# A   C
# bar large  5.500000  7.0  5.500000  4.0
#     small  5.500000  6.0  5.500000  5.0
# foo large  2.000000  2.0  2.000000  2.0
#     small  2.333333  3.0  2.333333  1.0

# %%
table.columns
# Out:
# MultiIndex([('D', 'mean'),
#             ('E',  'max'),
#             ('E', 'mean'),
#             ('E',  'min')],
#            )

# %%
table.index
# Out:
# MultiIndex([('bar', 'large'),
#             ('bar', 'small'),
#             ('foo', 'large'),
#             ('foo', 'small')],
#            names=['A', 'C'])

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby(["pclass", "sex"])["survived"].mean()
# Out:
# pclass  sex
# 1       female    0.965278
#         male      0.340782
# 2       female    0.886792
#         male      0.146199
# 3       female    0.490741
#         male      0.152130
# Name: survived, dtype: float64

# %%
titanic.groupby(["embarked"])["survived"].agg(["mean", "count"])
# Out:
#               mean  count
# embarked
# C         0.555556    270
# Q         0.357724    123
# S         0.332604    914

# %%
df = pd.DataFrame({'animal': 'cat dog cat fish dog cat cat'.split(),
                    'size': list('SSMMMLL'),
                    'weight': [8, 10, 11, 1, 20, 12, 12],
                    'adult': [False] * 5 + [True] * 2})
df
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 1    dog    S      10  False
# 2    cat    M      11  False
# 3   fish    M       1  False
# 4    dog    M      20  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
df.groupby('animal').apply(lambda subf: subf['size'][subf['weight'].idxmax()])
# Out:
# animal
# cat     L
# dog     M
# fish    M
# dtype: object

# %%
gb = df.groupby(['animal'])
gb.get_group('cat')
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 2    cat    M      11  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
def GrowUp(x):
    avg_weight = sum(x[x['size'] == 'S'].weight * 1.5)
    avg_weight += sum(x[x['size'] == 'M'].weight * 1.25)
    avg_weight += sum(x[x['size'] == 'L'].weight)
    avg_weight /= len(x)
    return pd.Series(['L', avg_weight, True], index=['size', 'weight', 'adult'])

# %%
gb.apply(GrowUp)
# Out:
#        size   weight  adult
# animal
# cat       L  12.4375   True
# dog       L  20.0000   True
# fish      L   1.2500   True

# %%
import functools
S = pd.Series([i / 100.0 for i in range(1, 11)])
def cum_ret(x, y):
    return x * (1 + y)
def red(x):
    return functools.reduce(cum_ret, x, 1.0)

# %%
S.expanding().apply(red, raw=True)
# Out:
# 0    1.010000
# 1    1.030200
# 2    1.061106
# 3    1.103550
# 4    1.158728
# 5    1.228251
# 6    1.314229
# 7    1.419367
# 8    1.547110
# 9    1.701821
# dtype: float64

# %%
S.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0]

# %%
S
# Out:
# 0    0.01
# 1    0.02
# 2    0.03
# 3    0.04
# 4    0.05
# 5    0.06
# 6    0.07
# 7    0.08
# 8    0.09
# 9    0.10
# dtype: float64

# %%
df = pd.DataFrame({'A': [1, 1, 2, 2, 3, 3, 3, 3], 'B': [1, -1, 1, 2, -1, -2, 1, 2]})
df
# Out:
#    A  B
# 0  1  1
# 1  1 -1
# 2  2  1
# 3  2  2
# 4  3 -1
# 5  3 -2
# 6  3  1
# 7  3  2

# %%
gb = df.groupby('A')
def replace(g):
    mask = g > 0
    return g.where(~mask, g[~mask].mean())
gb.transform(replace)
# Out:
#      B
# 0 -1.0
# 1 -1.0
# 2  NaN
# 3  NaN
# 4 -1.0
# 5 -2.0
# 6 -1.5
# 7 -1.5

# %%
gap = pd.read_csv('gapminder_tidy.csv')
gap
# Out:
#            Country  Year  fertility    life  population  child_mortality  \
# 0      Afghanistan  1964      7.671  33.639  10474903.0            339.7
# 1      Afghanistan  1965      7.671  34.152  10697983.0            334.1
# 2      Afghanistan  1966      7.671  34.662  10927724.0            328.7
# 3      Afghanistan  1967      7.671  35.170  11163656.0            323.3
# 4      Afghanistan  1968      7.671  35.674  11411022.0            318.1
# ...            ...   ...        ...     ...         ...              ...
# 10106        Åland  2002        NaN  81.800     26257.0              NaN
# 10107        Åland  2003        NaN  80.630     26347.0              NaN
# 10108        Åland  2004        NaN  79.880     26530.0              NaN
# 10109        Åland  2005        NaN  80.000     26766.0              NaN
# 10110        Åland  2006        NaN  80.100     26923.0              NaN
#
#           gdp                 region
# 0      1182.0             South Asia
# ...

# %%
standardized = gap.groupby('region')['life', 'fertility'].transform(zscore)
standardized
# Out:
#            life  fertility
# 0     -2.289170   1.477737
# 1     -2.239195   1.477737
# 2     -2.189513   1.477737
# 3     -2.140025   1.477737
# 4     -2.090927   1.477737
# ...         ...        ...
# 10106  1.917707        NaN
# 10107  1.690350        NaN
# 10108  1.544608        NaN
# 10109  1.567927        NaN
# 10110  1.587359        NaN
#
# [10111 rows x 2 columns]

# %%
gap.loc[(standardized['life'] < -3) & (gap['Year'] == 1966) ]
# Out:
#           Country  Year  fertility    life  population  child_mortality  \
# 1002      Bolivia  1966      6.586  44.536   3839751.0            254.5
# 3802        Haiti  1966      6.109  45.518   4359031.0            263.9
# 8952  Timor-Leste  1966      6.268  36.885    558110.0            301.2
# 9203       Turkey  1966      5.874  49.736  32556294.0            209.3
# 9953  Yemen, Rep.  1966      7.447  37.827   5737000.0              NaN
#
#          gdp                      region
# 1002  3191.0                     America
# 3802  1949.0                     America
# 8952   702.0         East Asia & Pacific
# 9203  5906.0       Europe & Central Asia
# 9953     NaN  Middle East & North Africa

# %%
grouped = titanic.groupby(['sex', 'pclass'])
def impute_median(series):
    return series.fillna(series.median())
titanic['age'] = grouped['age'].transform(impute_median)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1309 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
def disparity(gr):
    s = gr['gdp'].max() - gr['gdp'].min()
    z = (gr['gdp'] - gr['gdp'].mean())/gr['gdp'].std()
    return pd.DataFrame({'z(gdp)':z , 'regional spread(gdp)':s})

# %%
gap
# Out:
#            Country  Year  fertility    life  population  child_mortality  \
# 0      Afghanistan  1964      7.671  33.639  10474903.0            339.7
# 1      Afghanistan  1965      7.671  34.152  10697983.0            334.1
# 2      Afghanistan  1966      7.671  34.662  10927724.0            328.7
# 3      Afghanistan  1967      7.671  35.170  11163656.0            323.3
# 4      Afghanistan  1968      7.671  35.674  11411022.0            318.1
# ...            ...   ...        ...     ...         ...              ...
# 10106        Åland  2002        NaN  81.800     26257.0              NaN
# 10107        Åland  2003        NaN  80.630     26347.0              NaN
# 10108        Åland  2004        NaN  79.880     26530.0              NaN
# 10109        Åland  2005        NaN  80.000     26766.0              NaN
# 10110        Åland  2006        NaN  80.100     26923.0              NaN
#
#           gdp                 region
# 0      1182.0             South Asia
# ...

# %%
regional_disparity = gap.groupby('region').apply(disparity)

# %%
gap = pd.concat([gap, regional_disparity], axis='columns')

# %%
gap[gap['Country'].isin(['China'])]
# Out:
#      Country  Year  fertility      life    population  child_mortality  \
# 1800   China  1964      6.120  53.32072  6.961716e+08           130.77
# 1801   China  1965      6.022  55.64680  7.102903e+08           115.43
# 1802   China  1966      6.211  56.80320  7.276011e+08           120.80
# 1803   China  1967      5.252  58.38112  7.476788e+08           126.42
# 1804   China  1968      6.370  59.40520  7.696665e+08           132.30
# 1805   China  1969      5.670  60.96520  7.923087e+08           119.10
# 1806   China  1970      5.746  62.65080  8.146228e+08           113.30
# 1807   China  1971      5.396  63.73736  8.364315e+08           107.70
# 1808   China  1972      4.920  63.11888  8.578040e+08           102.10
# 1809   China  1973      4.506  62.78080  8.783051e+08            96.50
# 1810   China  1974      4.150  62.49960  8.974792e+08            90.90
# 1811   China  1975      3.576  62.69888  9.150410e+08            85.20
# ...

# %%
gap[gap['Country'].isin(['United States'])]
# Out:
#             Country  Year  fertility    life   population  child_mortality  \
# 9501  United States  1964    3.22200  70.330  197094531.0             27.7
# 9502  United States  1965    2.92600  70.410  199452508.0             27.1
# 9503  United States  1966    2.71400  70.430  201657141.0             26.4
# 9504  United States  1967    2.56400  70.760  203717833.0             25.7
# 9505  United States  1968    2.46700  70.420  205672498.0             24.9
# 9506  United States  1969    2.45700  70.660  207573866.0             24.1
# 9507  United States  1970    2.46100  70.920  209463865.0             23.3
# 9508  United States  1971    2.26800  71.240  211355529.0             22.4
# 9509  United States  1972    2.00800  71.340  213250350.0             21.5
# 9510  United States  1973    1.87100  71.540  215164616.0             20.6
# 9511  United States  1974    1.82700  72.080  217113584.0             19.7
# ...

# %%
def c_deck_survival(gr):
    c_passengers = gr['cabin'].str.startswith('C').fillna(False)
    return gr.loc[c_passengers, 'survived'].mean()

# %%
titanic.groupby('sex').apply(c_deck_survival)
# Out:
# sex
# female    0.913043
# male      0.312500
# dtype: float64

# %%
sales = pd.read_csv('sales-feb-2015.csv', index_col='Date', parse_dates=True)
sales
# Out:
#                              Company   Product  Units
# Date
# 2015-02-02 08:30:00            Hooli  Software      3
# 2015-02-02 21:00:00        Mediacore  Hardware      9
# 2015-02-03 14:00:00          Initech  Software     13
# 2015-02-04 15:30:00        Streeplex  Software     13
# 2015-02-04 22:00:00  Acme Coporation  Hardware     14
# 2015-02-05 02:00:00  Acme Coporation  Software     19
# 2015-02-05 22:00:00            Hooli   Service     10
# 2015-02-07 23:00:00  Acme Coporation  Hardware      1
# 2015-02-09 09:00:00        Streeplex   Service     19
# 2015-02-09 13:00:00        Mediacore  Software      7
# 2015-02-11 20:00:00          Initech  Software      7
# 2015-02-11 23:00:00            Hooli  Software      4
# 2015-02-16 12:00:00            Hooli  Software     10
# 2015-02-19 11:00:00        Mediacore  Hardware     16
# 2015-02-19 16:00:00        Mediacore   Service     10
# 2015-02-21 05:00:00        Mediacore  Software      3
# ...

# %%
bycompany = sales.groupby('Company')
bycompany['Units'].sum()
# Out:
# Company
# Acme Coporation    34
# Hooli              30
# Initech            30
# Mediacore          45
# Streeplex          36
# Name: Units, dtype: int64

# %%
bycompany.filter(lambda g: g['Units'].sum() > 35)
# Out:
#                        Company   Product  Units
# Date
# 2015-02-02 21:00:00  Mediacore  Hardware      9
# 2015-02-04 15:30:00  Streeplex  Software     13
# 2015-02-09 09:00:00  Streeplex   Service     19
# 2015-02-09 13:00:00  Mediacore  Software      7
# 2015-02-19 11:00:00  Mediacore  Hardware     16
# 2015-02-19 16:00:00  Mediacore   Service     10
# 2015-02-21 05:00:00  Mediacore  Software      3
# 2015-02-26 09:00:00  Streeplex   Service      4

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
under10 = (titanic['age'] < 10).map({True: 'Under 10', False: 'Over 10'})
under10
# Out:
# 0        Over 10
# 1       Under 10
# 2       Under 10
# 3        Over 10
# 4        Over 10
#           ...
# 1304     Over 10
# 1305     Over 10
# 1306     Over 10
# 1307     Over 10
# 1308     Over 10
# Name: age, Length: 1309, dtype: object

# %%
titanic.groupby(under10)['survived'].mean()
# Out:
# age
# Over 10     0.366748
# Under 10    0.609756
# Name: survived, dtype: float64

# %%
titanic.groupby([under10, 'pclass'])['survived'].agg(['count', sum, 'mean'])
# Out:
#                  count  sum      mean
# age      pclass
# Over 10  1         319  197  0.617555
#          2         255   97  0.380392
#          3         653  156  0.238897
# Under 10 1           4    3  0.750000
#          2          22   22  1.000000
#          3          56   25  0.446429

# %%
medals = pd.read_csv('all_medalists.csv')
medals
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
medals.loc[medals.NOC == 'USA'].groupby('Edition')['Medal'].count()
# Out:
# Edition
# 1896     20
# 1900     55
# 1904    394
# 1908     63
# 1912    101
# 1920    193
# 1924    198
# 1928     84
# 1932    181
# 1936     92
# 1948    148
# 1952    130
# 1956    118
# 1960    112
# 1964    150
# 1968    149
# 1972    155
# 1976    155
# 1984    333
# 1988    193
# 1992    224
# 1996    260
# 2000    248
# 2004    264
# 2008    315
# Name: Medal, dtype: int64

# %%
medals.loc[medals.NOC == 'CHN'].groupby(['Edition', 'Medal'])['Athlete'].count()
# Out:
# Edition  Medal
# 1984     Bronze    37
#          Gold      26
#          Silver    13
# 1988     Bronze    31
#          Gold       6
#          Silver    16
# 1992     Bronze    19
#          Gold      18
#          Silver    46
# 1996     Bronze    17
#          Gold      19
#          Silver    74
# 2000     Bronze    17
#          Gold      39
#          Silver    23
# 2004     Bronze    15
#          Gold      52
#          Silver    27
# 2008     Bronze    57
#          Gold      74
#          Silver    53
# Name: Athlete, dtype: int64

# %%
medals.loc[medals.NOC == 'ROU'].groupby(['Edition', 'Medal'])['Athlete'].count()
# Out:
# Edition  Medal
# 1924     Bronze    23
# 1936     Silver     2
# 1952     Bronze     2
#          Gold       1
#          Silver     1
# 1956     Bronze    10
#          Gold       6
#          Silver     3
# 1960     Bronze    11
#          Gold       3
#          Silver     1
# 1964     Bronze    10
#          Gold       2
#          Silver     4
# 1968     Bronze     9
#          Gold       5
#          Silver     9
# 1972     Bronze    27
#          Gold       3
#          Silver    10
# 1976     Bronze    23
#          Gold       4
#          Silver    28
# 1980     Bronze    50
#          Gold       7
#          Silver    15
# 1984     Bronze    35
#          Gold      40
#          Silver    31
# 1988     Bronze    13
#          Gold       8
#          Silver    30
# 1992     Bronze    14
#          Gold       8
#          Silver    31
# 1996     Bronze    15
#          Gold      13
#          Silver    10
# 2000     Bronze    13
#          Gold      27
# ...

# %%
medals['NOC'].value_counts()[:15]
# Out:
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
# GER    1211
# AUS    1075
# HUN    1053
# SWE    1021
# GDR     825
# NED     782
# JPN     704
# CHN     679
# RUS     638
# ROU     624
# Name: NOC, dtype: int64

# %%
medals.pivot_table(aggfunc='count', index='NOC', values='Athlete', columns='Medal', 
                   fill_value=0).sum(axis=1).sort_values(ascending=False)[:15]
# Out:
# NOC
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
# GER    1211
# AUS    1075
# HUN    1053
# SWE    1021
# GDR     825
# NED     782
# JPN     704
# CHN     679
# RUS     638
# ROU     624
# dtype: int64

# %%
medals.groupby(['Event_gender', 'Gender'])['Medal'].count().sort_values(ascending=False)
# Out:
# Event_gender  Gender
# M             Men       20067
# W             Women      7277
# X             Men        1653
#               Women       218
# W             Men           1
# Name: Medal, dtype: int64

# %%
medals.groupby('NOC')['Sport'].nunique().sort_values(ascending=False)[:15]
# Out:
# NOC
# USA    34
# GBR    31
# FRA    28
# GER    26
# CHN    24
# AUS    22
# ESP    22
# CAN    22
# SWE    21
# URS    21
# ITA    21
# NED    20
# RUS    20
# JPN    20
# DEN    19
# Name: Sport, dtype: int64

# %%
coldwar = medals.loc[medals['Edition'].between(1952, 1988) & medals['NOC'].isin(['USA', 'URS'])]
coldwar.groupby(['NOC', 'Medal'])['Medal'].count()
# Out:
# NOC  Medal
# URS  Bronze    584
#      Gold      838
#      Silver    627
# USA  Bronze    321
#      Gold      730
#      Silver    444
# Name: Medal, dtype: int64

# %%
coldwar_tab = medals.pivot_table(index='Edition', columns='NOC', values='Athlete', aggfunc='count')
coldwar_tab.loc[1952:1988, ['USA', 'URS']]
# Out:
# NOC        USA    URS
# Edition
# 1952     130.0  117.0
# 1956     118.0  169.0
# 1960     112.0  169.0
# 1964     150.0  174.0
# 1968     149.0  188.0
# 1972     155.0  211.0
# 1976     155.0  285.0
# 1980       NaN  442.0
# 1984     333.0    NaN
# 1988     193.0  294.0

# %%
coldwar_tab.loc[1952:1988, ['USA', 'URS']].idxmax(axis=1)
# Out:
# Edition
# 1952    USA
# 1956    URS
# 1960    URS
# 1964    URS
# 1968    URS
# 1972    URS
# 1976    URS
# 1980    URS
# 1984    USA
# 1988    URS
# dtype: object

# %%
coldwar_tab.loc[1952:1988, ['USA', 'URS']].idxmax()
# Out:
# NOC
# USA    1984
# URS    1980
# dtype: int64

# %%
coldwar_tab.loc[1952:1988, ['USA', 'URS']].max()
# Out:
# NOC
# USA    333.0
# URS    442.0
# dtype: float64

# %%
coldwar_tab.loc[1952:1988, ['USA', 'URS']].max(axis=1)
# Out:
# Edition
# 1952    130.0
# 1956    169.0
# 1960    169.0
# 1964    174.0
# 1968    188.0
# 1972    211.0
# 1976    285.0
# 1980    442.0
# 1984    333.0
# 1988    294.0
# dtype: float64

# %%
usa = medals[medals['NOC'] == 'USA'].groupby(['Edition', 'Medal'])['Athlete'].count().unstack('Medal')
usa
# Out:
# Medal    Bronze  Gold  Silver
# Edition
# 1896          2    11       7
# 1900         14    27      14
# 1904        111   146     137
# 1908         15    34      14
# 1912         31    45      25
# 1920         38   110      45
# 1924         51   110      37
# 1928         17    43      24
# 1932         59    78      44
# 1936         15    51      26
# 1948         35    83      30
# 1952         28    79      23
# 1956         20    61      37
# 1960         21    68      23
# 1964         36    78      36
# 1968         35    83      31
# 1972         43    53      59
# 1976         36    63      56
# 1984         50   168     115
# 1988         52    77      64
# 1992         85    89      50
# 1996         52   160      48
# 2000         52   130      66
# 2004         73   116      75
# 2008         81   125     109

# %%
usa.plot();

# %%
usa.plot.area();

# %%
medals['Medal'] = pd.Categorical(values=medals['Medal'], categories=['Bronze', 'Silver', 'Gold'], ordered=True)
medals
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
usa = medals[medals['NOC'] == 'USA'].groupby(['Edition', 'Medal'])['Athlete'].count().unstack('Medal')
usa
# Out:
# Medal    Bronze  Silver  Gold
# Edition
# 1896          2       7    11
# 1900         14      14    27
# 1904        111     137   146
# 1908         15      14    34
# 1912         31      25    45
# 1920         38      45   110
# 1924         51      37   110
# 1928         17      24    43
# 1932         59      44    78
# 1936         15      26    51
# 1948         35      30    83
# 1952         28      23    79
# 1956         20      37    61
# 1960         21      23    68
# 1964         36      36    78
# 1968         35      31    83
# 1972         43      59    53
# 1976         36      56    63
# 1984         50     115   168
# 1988         52      64    77
# 1992         85      50    89
# 1996         52      48   160
# 2000         52      66   130
# 2004         73      75   116
# 2008         81     109   125

# %%
usa.plot.area();
